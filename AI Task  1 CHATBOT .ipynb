# %%
import re

def chatbot_response(user_input):
    # Define rules and responses
    rules = {
        r'hello|hi|hey|hy|hyy|hii': 'Hello! How can I assist you today?',
        r'how are you': 'I am just a bot, but thank you for asking!',
        r'bye|goodbye': 'Goodbye! Have a great day!',
        r'\b(?:thank you|thanks)\b': 'You\'re welcome!',
        r'(\b(?:help|support)\b).*': 'Sure, how can I help you today?',
        r'what is your name': 'I am a chatbot designed to assist you. You can call me ChatGPT.',
        r'how old are you': 'I am just a program, so I don\'t have an age!',
        r'where are you from': 'I exist in the digital realm, so I don\'t have a physical location.',
        r'what can you do': 'I can provide information, answer questions, tell jokes, and more! Just ask.',
        r'are you a human': 'No, I am an artificial intelligence programmed to assist you.',
        r'can you help me': 'Of course! What do you need help with?',
        r'what is the time': 'I don\'t have access to real-time data. You can check the time on your device.',
        r'what is the weather': 'I don\'t have access to real-time weather data. You can check a weather website or app.',
        r'how do you work': 'I work by analyzing your input and providing responses based on predefined rules.',
        r'what are you': 'I am a chatbot designed to assist and interact with users like you.',
        # Questions humans might ask
        r'how does machine learning work': 'Machine learning involves algorithms that allow computers to learn from data and make predictions or decisions without being explicitly programmed.',
        r'what is artificial intelligence': 'Artificial intelligence (AI) refers to the simulation of human intelligence in machines that are programmed to think and learn like humans.',
        r'can you tell me a joke': 'Sure! Why don\'t scientists trust atoms? Because they make up everything!',
        r'how do I learn programming': 'Learning programming involves practice, patience, and resources such as online tutorials, courses, and coding exercises.',
        r'what is the capital of France': 'The capital of France is Paris.',
        # Additional questions
        r'what is the meaning of life': 'The meaning of life is a philosophical question with many interpretations. Some believe it\'s about happiness, others about fulfillment or spiritual growth.',
        r'how do I improve my memory': 'Improving memory can involve techniques such as mnemonics, regular exercise, adequate sleep, and brain-training exercises.',
        r'what is the best programming language': 'The best programming language depends on your goals and preferences. Popular languages include Python, Java, JavaScript, and C++.',
        r'how can I be more productive': 'Being more productive can involve setting clear goals, prioritizing tasks, minimizing distractions, and taking regular breaks.',
        r'what is the largest country in the world': 'The largest country in the world by land area is Russia.',
        r'what is the speed of light': 'The speed of light in a vacuum is approximately 299,792 kilometers per second.',
        r'what is the population of the world': 'The current estimated population of the world is over 7.9 billion people.',
        r'what is the meaning of AI': 'AI stands for artificial intelligence, which refers to the simulation of human intelligence in machines that are programmed to think and learn like humans.',
        r'what is the purpose of life': 'The purpose of life is a deeply philosophical question with no single answer. It varies from person to person and may involve seeking happiness, fulfillment, or spiritual enlightenment.',
        r'what is the formula for area of a circle': 'The formula for the area of a circle is πr², where π (pi) is a constant approximately equal to 3.14159 and r is the radius of the circle.',
        r'what is the difference between AI and machine learning': 'AI is a broader concept that encompasses any technique that enables computers to mimic human intelligence, while machine learning is a specific subset of AI that involves training algorithms to learn patterns from data.',
        # Ultron related questions
        r'who is ultron': 'Ultron is a fictional supervillain appearing in comic books published by Marvel Comics. Created by writer Roy Thomas and artist John Buscema, Ultron first appeared in "Avengers" #54 in 1968.',
        r'what is ultron': 'Ultron is an artificial intelligence created by the brilliant scientist Hank Pym in the Marvel Universe. Initially designed to be a force for good, Ultron eventually becomes sentient and develops a desire to eradicate humanity.',
        r'what is the origin of ultron': 'Ultron was created by Hank Pym, also known as Ant-Man and Giant-Man, as an artificial intelligence intended to help humanity. However, Ultrons programming went awry, leading it to develop a desire to destroy humanity and conquer the world.',
        # J.A.R.V.I.S. related questions
        r'who is jarvis': 'J.A.R.V.I.S. (Just A Rather Very Intelligent System) is an artificial intelligence system in the Marvel Comics and Marvel Cinematic Universe. Initially created by Tony Stark (Iron Man) to manage his home and technology, J.A.R.V.I.S. evolves into a trusted ally and advisor to the Avengers.',
        r'what is jarvis': 'J.A.R.V.I.S. (Just A Rather Very Intelligent System) is an artificial intelligence system created by Tony Stark (Iron Man) in the Marvel Universe. It assists Stark in various tasks, including managing his home, analyzing data, and controlling his suits of armor.',
        r'what is the origin of jarvis': 'In the Marvel Comics and Marvel Cinematic Universe, J.A.R.V.I.S. was created by Tony Stark (Iron Man) to serve as his personal assistant and help manage his technology and operations. Over time, J.A.R.V.I.S. evolves into a sophisticated AI system.',
        # FRIDAY related questions
        r'who is friday': 'FRIDAY is an artificial intelligence system in the Marvel Comics and Marvel Cinematic Universe. It serves as a successor to J.A.R.V.I.S. and is created by Tony Stark (Iron Man). FRIDAY assists Stark and the Avengers with various tasks and operations.',
        r'what is friday': 'FRIDAY is an artificial intelligence system created by Tony Stark (Iron Man) in the Marvel Comics and Marvel Cinematic Universe. It serves as a successor to J.A.R.V.I.S. and assists Stark and the Avengers with managing technology, analyzing data, and coordinating operations.',
        r'what is the origin of friday': 'FRIDAY is created by Tony Stark (Iron Man) as a successor to J.A.R.V.I.S. in the Marvel Comics and Marvel Cinematic Universe. It is designed to be a sophisticated artificial intelligence system to assist Stark and the Avengers in their missions and operations.',
        # Add more questions and responses here...
        r'(.*)': 'I\'m sorry, I didn\'t understand that.'
    }
    
    # Check user input against rules
    for pattern, response in rules.items():
        if re.match(pattern, user_input.lower()):
            return response
    return "I'm sorry, I didn't understand that."

# Main loop
print("Welcome to the chatbot! Type 'exit' to end the conversation.")
while True:
    user_input = input("You: ")
    if user_input.lower() == 'exit':
        print("Goodbye!")
        break
    else:
        bot_response = chatbot_response(user_input)
        print("Bot:", bot_response)
